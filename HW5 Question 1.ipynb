# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import numpy as np
import torch

# %%
#Creating the tensors for the temperature in celcius- target(t_c) and the temperature in farenheit- input(t_u)
t_c = [0.5,  14.0, 15.0, 28.0, 11.0,  8.0,  3.0, -4.0,  6.0, 13.0, 21.0]
t_u = [35.7, 55.9, 58.2, 81.9, 56.3, 48.9, 33.9, 21.8, 48.4, 60.4, 68.4]
t_c = torch.tensor(t_c).unsqueeze(1)
t_u = torch.tensor(t_u).unsqueeze(1)
t_un = 0.1 * t_u

# %%
#Definition of the equation model
def model(t_u, w1, w2, b):
    return w2 * t_u ** 2 + w1 * t_u + b

#Defining MSE
def loss_fn(t_p, t_c):
    squared_diffs = (t_p - t_c)**2
    return squared_diffs.mean()

#Initializing the weights
w1 = torch.ones(())
w2 = torch.ones(())
b = torch.zeros(())

t_p = model(t_u, w1, w2, b)
t_p
# Out:
# tensor([[1310.1901],
#         [3180.7100],
#         [3445.4399],
#         [6789.5103],
#         [3225.9900],
#         [2440.1101],
#         [1183.1101],
#         [ 497.0399],
#         [2390.9600],
#         [3708.5601],
#         [4746.9600]])

# %%
#loss
loss = loss_fn(t_p, t_c)
loss
# Out:
# tensor(11709471.)

# %%
#Defining the step size
delta = 0.1

loss_rate_of_change_w1 = \
    (loss_fn(model(t_u, w1 + delta, w2, b), t_c) - 
     loss_fn(model(t_u, w1 - delta, w2, b), t_c)) / (2.0 * delta)
loss_rate_of_change_w2 = \
    (loss_fn(model(t_u, w1, w2 + delta, b), t_c) - 
     loss_fn(model(t_u, w1, w2 - delta, b), t_c)) / (2.0 * delta)

learning_rate = 1e-2

w1 = w1 - learning_rate * loss_rate_of_change_w1
w2 = w2 - learning_rate * loss_rate_of_change_w2

loss_rate_of_change_b = \
    (loss_fn(model(t_u, w1, w2, b + delta), t_c) - 
     loss_fn(model(t_u, w1, w2, b - delta), t_c)) / (2.0 * delta)

b = b - learning_rate * loss_rate_of_change_b

def dloss_fn(t_p, t_c):
    dsq_diffs = 2 * (t_p - t_c) / t_p.size(0)  # <1>
    return dsq_diffs

def dmodel_dw1(t_u, w1, w2, b):
    return t_u

def dmodel_dw2(t_u, w1, w2, b):
    return t_u

def dmodel_db(t_u, w1, w2, b):
    return 1.0

def grad_fn(t_u, t_c, t_p, w1, w2, b):
    dloss_dtp = dloss_fn(t_p, t_c)
    dloss_dw1 = dloss_dtp * dmodel_dw1(t_u, w1, w2, b)
    dloss_dw2 = dloss_dtp * dmodel_dw2(t_u, w1, w2, b)
    dloss_db = dloss_dtp * dmodel_db(t_u, w1, w2, b)
    return torch.stack([dloss_dw1.sum(), dloss_dw2.sum(), dloss_db.sum()])  # <1>

# %%
#Defining the training loop 
def training_loop(n_epochs, learning_rate, params, t_u, t_c):
    for epoch in range(1, n_epochs + 1):
        w1, w2, b = params

        t_p = model(t_u, w1, w2, b)  # <1>
        loss = loss_fn(t_p, t_c)
        grad = grad_fn(t_u, t_c, t_p, w1, w2, b)  # <2>

        params = params - learning_rate * grad

        if epoch % 500 == 0:
            print('Epoch %d, Loss %f' % (epoch, float(loss))) # <3>
            
    return params

# %%
#2000 epochs, learning rate - 0.1
training_loop(
    n_epochs = 2000, 
    learning_rate = 1e-1, 
    params = torch.tensor([1.0, 1.0, 0.0]), 
    t_u = t_u, 
    t_c = t_c)
# Out:
# Epoch 500, Loss nan
# Epoch 1000, Loss nan
# Epoch 1500, Loss nan
# Epoch 2000, Loss nan
# tensor([nan, nan, nan])

# %%
#2000 epochs, learning rate - 0.1 standardized input
params = training_loop(
    n_epochs = 2000, 
    learning_rate = 1e-1, 
    params = torch.tensor([1.0, 1.0, 0.0]), 
    t_u = t_un, # <1>
    t_c = t_c)
# Out:
# Epoch 500, Loss nan
# Epoch 1000, Loss nan
# Epoch 1500, Loss nan
# Epoch 2000, Loss nan

# %%
#2000 epochs, learning rate - 0.01
params = training_loop(
    n_epochs = 2000, 
    learning_rate = 1e-2, 
    params = torch.tensor([1.0, 1.0, 0.0]), 
    t_u = t_u, 
    t_c = t_c)
# Out:
# Epoch 500, Loss nan
# Epoch 1000, Loss nan
# Epoch 1500, Loss nan
# Epoch 2000, Loss nan

# %%
#2000 epochs, learning rate - 0.01 standardized input
params = training_loop(
    n_epochs = 2000, 
    learning_rate = 1e-2, 
    params = torch.tensor([1.0, 1.0, 0.0]), 
    t_u = t_un, 
    t_c = t_c)
# Out:
# Epoch 500, Loss nan
# Epoch 1000, Loss nan
# Epoch 1500, Loss nan
# Epoch 2000, Loss nan

# %%
#2000 epochs, learning rate - 0.001
params = training_loop(
    n_epochs = 2000, 
    learning_rate = 1e-3, 
    params = torch.tensor([1.0, 1.0, 0.0]), 
    t_u = t_u, 
    t_c = t_c)
# Out:
# Epoch 500, Loss nan
# Epoch 1000, Loss nan
# Epoch 1500, Loss nan
# Epoch 2000, Loss nan

# %%
#2000 epochs, learning rate - 0.001 standardized input
params = training_loop(
    n_epochs = 2000, 
    learning_rate = 1e-3, 
    params = torch.tensor([1.0, 1.0, 0.0]), 
    t_u = t_un, 
    t_c = t_c)
# Out:
# Epoch 500, Loss 8.035689
# Epoch 1000, Loss 6.636409
# Epoch 1500, Loss 5.582901
# Epoch 2000, Loss 4.790622

# %%
#2000 epochs, learning rate - 0.0001
params = training_loop(
    n_epochs = 2000, 
    learning_rate = 1e-4, 
    params = torch.tensor([1.0, 1.0, 0.0]), 
    t_u = t_u, 
    t_c = t_c)
# Out:
# Epoch 500, Loss nan
# Epoch 1000, Loss nan
# Epoch 1500, Loss nan
# Epoch 2000, Loss nan

# %%
#2000 epochs, learning rate - 0.0001 standardized input
params = training_loop(
    n_epochs = 2000, 
    learning_rate = 1e-4, 
    params = torch.tensor([1.0, 1.0, 0.0]), 
    t_u = t_un, 
    t_c = t_c)
# Out:
# Epoch 500, Loss 9.678580
# Epoch 1000, Loss 9.474418
# Epoch 1500, Loss 9.275946
# Epoch 2000, Loss 9.082996

# %%
#Plotting the values. 
fig = plt.figure(dpi=600)
t_p = model(t_un, *params)
plt.xlabel("Temperature (°Fahrenheit)")
plt.ylabel("Temperature (°Celsius)")
plt.plot(t_u.numpy(), t_p.detach().numpy())
plt.plot(t_u.numpy(), t_c.numpy(), 'o')
